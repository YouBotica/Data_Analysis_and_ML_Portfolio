# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Text Classification Assessment
#
# ### Goal: Given a set of text movie reviews that have been labeled negative or positive
#
# For more information on this dataset visit http://ai.stanford.edu/~amaas/data/sentiment/
#
# ## Complete the tasks in bold below!

# %% [markdown]
# **Task: Perform imports and load the dataset into a pandas DataFrame**
# For this exercise you can load the dataset from `'../DATA/moviereviews.csv'`.

# %%
# CODE HERE

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../DATA/moviereviews.csv')

# %%
df.head()
# Out:
#   label                                             review
# 0   neg  how do films like mouse hunt get into theatres...
# 1   neg  some talented actresses are blessed with a dem...
# 2   pos  this has been an extraordinary year for austra...
# 3   pos  according to hollywood movies made in last few...
# 4   neg  my first press screening of 1998 and already i...

# %% [markdown]
# **TASK: Check to see if there are any missing values in the dataframe.**

# %%
#CODE HERE
df.isnull().sum()
# Out:
# label      0
# review    35
# dtype: int64

# %%
# Out:
# label      0
# review    35
# dtype: int64

# %% [markdown]
# **TASK: Remove any reviews that are NaN**

# %%
df = df.dropna(axis=0)

# %% [markdown]
# **TASK: Check to see if any reviews are blank strings and not just NaN. Note: This means a review text could just be: "" or "  " or some other larger blank string. How would you check for this? Note: There are many ways! Once you've discovered the reviews that are blank strings, go ahead and remove them as well. [Click me for a big hint](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.isspace.html)**

# %%
df.replace("  ", float("NaN"), inplace=True)

# %%
df = df.dropna(axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1938 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   1938 non-null   object
#  1   review  1938 non-null   object
# dtypes: object(2)
# memory usage: 45.4+ KB

# %%
# Out:
#      label review
# 57     neg
# 71     pos
# 147    pos
# 151    pos
# 283    pos
# 307    pos
# 313    neg
# 323    pos
# 343    pos
# 351    neg
# 427    pos
# 501    neg
# 633    pos
# 675    neg
# 815    neg
# 851    neg
# 977    neg
# 1079   neg
# 1299   pos
# 1455   neg
# 1493   pos
# 1525   neg
# 1531   neg
# 1763   neg
# 1851   neg
# 1905   pos
# 1993   pos

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1938 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   1938 non-null   object
#  1   review  1938 non-null   object
# dtypes: object(2)
# memory usage: 45.4+ KB

# %% [markdown]
# **TASK: Confirm the value counts per label:**

# %%
#CODE HERE
df['label'].value_counts()
# Out:
# neg    969
# pos    969
# Name: label, dtype: int64

# %%
# Out:
# pos    969
# neg    969
# Name: label, dtype: int64

# %% [markdown]
# ## EDA on Bag of Words
#
# **Bonus Task: Can you figure out how to use a CountVectorizer model to get the top 20 words (that are not english stop words) per label type? Note, this is a bonus task as we did not show this in the lectures. But a quick cursory Google search should put you on the right path.  [Click me for a big hint](https://stackoverflow.com/questions/16288497/find-the-most-common-term-in-scikit-learn-classifier)**

# %%
#CODE HERE
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vectorizer = CountVectorizer(stop_words='english')

# %%
X = df['review']

# %%
y = df['label']

# %%
count_vectorizer.fit_transform(X)
# Out:
# <1938x38596 sparse matrix of type '<class 'numpy.int64'>'
# 	with 470990 stored elements in Compressed Sparse Row format>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_25369/1740786030.py in <module>
# ----> 1 count_vectorizer.get_feature_names_out()
#
# AttributeError: 'CountVectorizer' object has no attribute 'get_feature_names_out'

# %%
# Out:
# The scikit-learn version is 0.24.2.

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_9585/424956335.py in <module>
# ----> 1 get_top_n_words(X_vectorized, 20)
#
# /tmp/ipykernel_9585/3007249107.py in get_top_n_words(corpus, n)
#      13      ('language', 1)]
#      14     """
# ---> 15     vec = CountVectorizer().fit(corpus)
#      16     bag_of_words = vec.transform(corpus)
#      17     sum_words = bag_of_words.sum(axis=0)
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py in fit(self, raw_documents, y)
#    1167         """
#    1168         self._warn_for_unused_params()
# -> 1169         self.fit_transform(raw_documents)
#    1170         return self
#    1171
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1200         max_features = self.max_features
#    1201
# ...

# %%
# Out:
# Top 20 words used for Negative reviews.
# [('film', 4063), ('movie', 3131), ('like', 1808), ('just', 1480), ('time', 1127), ('good', 1117), ('bad', 997), ('character', 926), ('story', 908), ('plot', 888), ('characters', 838), ('make', 813), ('really', 743), ('way', 734), ('little', 696), ('don', 683), ('does', 666), ('doesn', 648), ('action', 635), ('scene', 634)]

# %%
# Out:
# Top 20 words used for Positive reviews.
# [('film', 5002), ('movie', 2389), ('like', 1721), ('just', 1273), ('story', 1199), ('good', 1193), ('time', 1175), ('character', 1037), ('life', 1032), ('characters', 957), ('way', 864), ('films', 851), ('does', 828), ('best', 788), ('people', 769), ('make', 764), ('little', 751), ('really', 731), ('man', 728), ('new', 702)]

# %% [markdown]
# ### Training and Data
#
# **TASK: Split the data into features and a label (X and y) and then preform a train/test split. You may use whatever settings you like. To compare your results to the solution notebook, use `test_size=0.20, random_state=101`**

# %%
#CODE HERE
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words='english')

# %%
X_train_tf = tfidf.fit_transform(X_train) # Avoid Data Leakage

# %%
X_test_tf = tfidf.transform(X_test)

# %% [markdown]
# ### Logistic Regression:

# %%
from sklearn.metrics import plot_confusion_matrix, classification_report

# %%
def report(model):
    predictions = model.predict(X_test_tf, y_test)
    print(classification_report(y_test, predictions))
    plot_confusion_matrix(model, X_test_tf, y_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# %%
log_model = LogisticRegression()

# %%
param_grid = {'penalty': ['l1', 'l2', 'elasticnet'], # Lasso, Ridge, and both
             'C': [0.01, 0.1, 1.0, 50, 100, 1000],
              'solver': ['lbfgs', 'sag', 'saga']
             }

# %%
grid_log_model = GridSearchCV(log_model, param_grid=param_grid, cv=10) # Cross Validation

# %%
grid_log_model.fit(X_train_tf, y_train)
# Out:
# /home/legacy/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/legacy/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/legacy/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/home/legacy/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# ...

# %% [markdown]
# ### Training a Mode
#
# **TASK: Create a PipeLine that will both create a TF-IDF Vector out of the raw text data and fit a supervised learning model of your choice. Then fit that pipeline on the training data.**

# %%
#CODE HERE

# %%
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('svc', LinearSVC())])

# %% [markdown]
# **TASK: Create a classification report and plot a confusion matrix based on the results of your PipeLine.**

# %%
#CODE HERE

# %%
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.81      0.86      0.83       191
#          pos       0.85      0.81      0.83       197
#
#     accuracy                           0.83       388
#    macro avg       0.83      0.83      0.83       388
# weighted avg       0.83      0.83      0.83       388

# %% [markdown]
# ## Great job!
